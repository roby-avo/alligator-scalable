# %%
import os
import numpy as np
import pandas as pd
import math
import time
from lamAPI import LamAPI


SAMPLE_SIZE = 25
LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]

def clean_str(value):
    value = str(value)
    stop_charaters = ["_"]
    for char in stop_charaters:
        value = value.replace(char, " ")
    value = " ".join(value.split()).lower()
    return value


def format_table(table_df):
    rows = []

    for id_row, row in enumerate(table_df):
        rows.append({"idRow":id_row+1, "data":[clean_str(cell) for cell in row]})
    #buffer = []
    #rows = np.array_split(rows, max(math.floor(len(rows)/SAMPLE_SIZE), 1))
        
    return rows


def compute_datatype(rows, lamapi_wrapper):
    column_metadata = {}
    columns_data = {str(i):[] for i in range(0, len(rows[0]['data']))}
    target = {"SUBJ": 0, "NE": [], "LIT": [], "LIT_DATATYPE": {}}
    for row in rows:
        for id_col, cell in enumerate(row["data"]):
            columns_data[str(id_col)].append(str(cell))
    
    first_NE_column = False     
    for id_col in columns_data:
        metadata = lamapi_wrapper.literal_recognizer(columns_data[id_col])
        max_datatype = max(metadata, key=metadata.get)
        if max_datatype == "ENTITY":
            column_metadata[id_col] = "NE"
            target['NE'].append(int(id_col)) 
            if not first_NE_column:
                target["SUBJ"] = int(id_col)
            first_NE_column = True
        else:
            column_metadata[id_col] = "LIT"
            target['LIT'].append(int(id_col))
            target['LIT_DATATYPE'][str(id_col)] = max_datatype
            
    return column_metadata, target        


lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN)
time = time
name = "film.csv"
input_file = pd.read_csv(name)
rows = format_table(input_file.values.tolist())
header = list(input_file.columns)
kg_reference = "wikidata"
column_metadata = {}
target = None


output = {
    "name": name,
    "header": header,
    "rows": rows,
    "metadata": None,
    "target": None,
    "kg_reference": kg_reference,
    "limit": 100,
    "status": "DONE", 
    "time": time.time()
}

if len(column_metadata) == 0:
        column_metadata, target = compute_datatype(rows, lamAPI)
        column_metadata[str(target["SUBJ"])] = "SUBJ"
        #output["column"] = column_metadata
        output["metadata"] = {
            "column": [{"idColumn": int(id_col), "tag": column_metadata[id_col]} for id_col in column_metadata]
        }
        output["target"] = target

# %%
output
# Out:
# {'name': 'film.csv',
#  'header': ['title',
#   'director',
#   'release year',
#   'domestic distributor',
#   'length in min',
#   'worldwide gross'],
#  'rows': [{'idRow': 1,
#    'data': ['jurassic world',
#     'colin trevorrow',
#     '2015',
#     'universal pictures',
#     '124',
#     '1670400637']},
#   {'idRow': 2,
#    'data': ['superman returns',
#     'bryan singer',
#     '2006',
#     'warner bros.',
#     '154',
#     '391081192']},
#   {'idRow': 3,
#    'data': ['batman begins',
#     'christopher nolan',
#     '2005',
#     'warner bros.',
#     '140',
#     '371853783']},
#   {'idRow': 4,
#    'data': ['avatar',
#     'james cameron',
#     '2009',
#     '20 century fox',
#     '162',
#     '2744336793']}],
#  'metadata': {'column': [{'idColumn': 0, 'tag': 'SUBJ'},
#    {'idColumn': 1, 'tag': 'NE'},
#    {'idColumn': 2, 'tag': 'LIT'},
#    {'idColumn': 3, 'tag': 'NE'},
#    {'idColumn': 4, 'tag': 'LIT'},
#    {'idColumn': 5, 'tag': 'LIT'}]},
#  'target': {'SUBJ': 0,
#   'NE': [0, 1, 3],
#   'LIT': [2, 4, 5],
#   'LIT_DATATYPE': {'2': 'NUMBER', '4': 'NUMBER', '5': 'NUMBER'}},
#  'kg_reference': 'wikidata',
#  'limit': 100,
#  'status': 'DONE',
#  'time': 1679130359.862871}

# %%
import os
import numpy as np
import pandas as pd
import math
import time
from lamAPI import LamAPI
from s2_process.process import Process

SAMPLE_SIZE = 25
LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]
lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN)
p1 = Process(output, lamAPI)
output["candidates"] = p1._rows

# %%
len(output["candidates"][3][1])
# Out:
# 65

# %%
"Q5145625" in temp["wikidata"]["Q3512046"]["objects"]
# Out:
# True

# %%
import metrics as metrics


class FeaturesExtraction:
    def __init__(self, data, lamAPI):
        self._data = data
        self._lamAPI = lamAPI
    
    
    def compute_features(self):
        rows = self._data["rows"]
        target = self._data["target"]
        for index, row in enumerate(rows):
            cells = row["data"]
            for id_col_ne_subj in target["NE"]:
                ne_cell_subj = cells[id_col_ne_subj]
                for id_col_ne_obj in target["NE"]:
                    if id_col_ne_subj == id_col_ne_obj:
                        continue
                    ne_cell_obj = cells[id_col_ne_obj]
                    self._compute_similarity_between_ne_cells(index, id_col_ne_subj, id_col_ne_obj)
                for id_col_lit_obj in target["LIT"]:
                    lit_cell_obj = cells[id_col_lit_obj]
                    self._match_lit_cells(index, id_col_ne_subj, id_col_ne_obj, lit_cell_obj, target["LIT_DATATYPE"][str(id_col_lit_obj)])
        self._extract_features()
        
        
    def _extract_features(self):
        features = [[] for id_col in range(len(self._data["metadata"]["column"]))]
        for row in self._data["candidates"]:
            for id_col, candidates in enumerate(row):
                for candidate in candidates:
                    features[id_col].append(list(candidate["features"].values()))
        self._data["features"] = features
    
    def _compute_similarity_between_ne_cells(self, id_row, id_col_subj_cell, id_col_obj_cell):
        subj_candidates = self._data["candidates"][id_row][id_col_subj_cell]
        obj_candidates = self._data["candidates"][id_row][id_col_obj_cell]
        subj_id_candidates = [candidate["id"] for candidate in subj_candidates]
        obj_id_candidates = [candidate["id"] for candidate in obj_candidates]
        
        subjects_objects = self._lamAPI.objects(subj_id_candidates)
        object_rel_score_buffer = {}

        for subj_candidate in subj_candidates:
            id_subject = subj_candidate["id"]
            subj_candidate_objects = subjects_objects.get(id_subject, {}).get("objects", {})
            objects_set = set(subj_candidate_objects.keys())
            #subj_candidate["matches"][str(id_col_obj_cell)] = []
            #subj_candidate["pred"][str(id_col_obj_cell)] = {}
              
            objects_itersection = objects_set.intersection(set(obj_id_candidates))
            #print(objects_itersection)
            obj_score_max = 0
            for obj_candidate in obj_candidates:
                id_object = obj_candidate["id"]  
                if id_object not in objects_itersection:
                    continue
                              
                score = obj_candidate["features"]["ed_score"]
                if score > obj_score_max:
                    obj_score_max = score
                   
                if id_object not in object_rel_score_buffer:
                    object_rel_score_buffer[id_object] = 0
                score_rel = subj_candidate["features"]["ed_score"]
                if score_rel > object_rel_score_buffer[id_object]:
                    object_rel_score_buffer[id_object] = score_rel
                for predicate in subj_candidate_objects[id_object]:
                    subj_candidate["matches"][str(id_col_obj_cell)].append({
                        "p": predicate,
                        "o": id_object,
                        "s": round(score, 3)
                    })
                    subj_candidate["predicates"][str(id_col_obj_cell)][predicate] = score
            subj_candidate["features"]["p_subj_ne"] += obj_score_max          
        
        for obj_candidate in obj_candidates:
            id_object = obj_candidate["id"]  
            if id_object not in object_rel_score_buffer:
                continue
            obj_candidate["features"]["p_obj_ne"] += object_rel_score_buffer[id_object]    
        
      
    def _match_lit_cells(self, id_row, id_col_subj_cell, id_col_obj_col, obj_cell, obj_cell_datatype):
    
        def get_score_based_on_datatype(valueInCell, valueFromKG, datatype):
            score = 0
            if datatype == "NUMBER":
                score = metrics.compute_similarty_between_numbers(valueInCell, valueFromKG.lower())
            elif datatype == "DATETIME":
                score = metrics.compute_similarity_between_dates(valueInCell, valueFromKG.lower())
            elif datatype == "STRING":
                score = metrics.compute_similarity_between_string(valueInCell, valueFromKg.lower())
            return score
        
        subj_candidates = self._data["candidates"][id_row][id_col_subj_cell]
        subj_id_candidates = [candidate["id"] for candidate in subj_candidates]
        cand_lamapi_literals = self._lamAPI.literals(subj_id_candidates)
        datatype = obj_cell_datatype
        
        for subj_candidate in subj_candidates:
            id_subject = subj_candidate["id"]
            literals = cand_lamapi_literals[id_subject]
            if "literals" in literals:
                literals = literals['literals']
            if len(literals[datatype.lower()]) == 0:
                continue
            #subj_candidate["matches"][str(id_col_obj_col)] = []
            #subj_candidate["pred"][str(id_col_obj_col)] = {}
            #subj_cell.candidates_entities()[subject]["match_count"]["lit"] += 1
            max_score = 0
            for predicate in literals[datatype.lower()]:
                for valueFromKg in literals[datatype.lower()][predicate]:
                    score = get_score_based_on_datatype(obj_cell, valueFromKg, datatype)
                    score = round(score, 3)
                    if score > 0:
                        subj_candidate["matches"][str(id_col_obj_col)].append({
                            "p": predicate,
                            "o": valueFromKg,
                            "s": round(score, 3)
                        })  
                        if score > max_score:
                            max_score = score
                        if predicate not in subj_candidate["predicates"][str(id_col_obj_col)]:
                            subj_candidate["predicates"][str(id_col_obj_col)][predicate] = 0
                        if score > subj_candidate["predicates"][str(id_col_obj_col)][predicate]:
                            subj_candidate["predicates"][str(id_col_obj_col)][predicate] = score    
                            
            subj_candidate["features"]["p_subj_lit"] += round(max_score, 3)

# %%
FeaturesExtraction(output, lamAPI).compute_features()

# %%
output["candidates"][2][1][0:2]

# %%
output["features"]

# %%
output["candidates"][0][2]

# %%
for row in output["candidates"]:
        for id_col, candidates in enumerate(row):

# %%
class Prediction:
    def __init__(self, data, model):
        self._data = data
        self._model = model
        
    def compute_prediction(self, feature_name):
        prediction = []
        indexes = []
        for column_features in self._data["features"]:
            pred = [] 
            if len(column_features) > 0:
                pred = self._model.predict(column_features)
            prediction.append(pred)
            indexes.append(0)
        
        for id_row, row in enumerate(self._data["candidates"]):
            for id_col, candidates in enumerate(row):
                for candidate in candidates:
                    index = indexes[id_col]
                    indexes[id_col] += 1
                    feature = round(prediction[id_col][index][1], 3)
                    candidate["features"][feature_name] = feature
                candidates.sort(key=lambda x:x["features"][feature_name], reverse=True)       
            #new_candidates = sorted(candidates, key=lambda x:x["features"]["cea"], reverse=True)
            #self._data["candidates"][id_row][id_col] = new_candidates

# %%
from keras.models import load_model
model = load_model("neural_network.h5")
Prediction(output, model).compute_prediction("cea")
# Out:
# 2023-03-18 16:09:26.201542: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-18 16:09:26.536105: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-18 16:09:26.536126: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-18 16:09:27.641428: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-18 16:09:27.641549: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-18 16:09:27.641560: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-18 16:09:28.616696: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-18 16:09:28.616934: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-18 16:09:28.616967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1df73a62b21c): /proc/driver/nvidia/version does not exist
# 2023-03-18 16:09:28.617455: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 8/8 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step

# %%
class FeaturesExtractionRevision:
    def __init__(self, data):
        self._data = data
        self._cta = {str(id_col):{} for id_col in range(len(self._data["metadata"]["column"]))}
        self._cpa = {str(id_col):{} for id_col in range(len(self._data["metadata"]["column"]))}
    
    def compute_features(self):
        for id_row, row in enumerate(self._data["candidates"]):
            for id_col, candidates in enumerate(row):
                id_col = str(id_col)
                history = set()
                for candidate in candidates[0:3]:
                    types = candidate["types"]
                    for t in types:
                        id_type = t["id"]
                        if id_type in history:
                            continue
                        if id_type not in self._cta[id_col]:
                            self._cta[id_col][id_type] = 0
                        self._cta[id_col][id_type] += 1
                        history.add(id_type)
                    
                    predicates = candidate["predicates"]
                    for id_col_rel in predicates:
                        for id_predicate in predicates[id_col_rel]:
                            if id_predicate in history:
                                continue
                            if id_predicate not in self._cpa[id_col]:
                                self._cpa[id_col][id_predicate] = 0
                            self._cpa[id_col][id_predicate] += 1
                            history.add(id_predicate)
        
        n_rows = len(self._data["rows"])
        for id_col in self._cta:
            for id_type in self._cta[id_col]:
                self._cta[id_col][id_type] = round(self._cta[id_col][id_type]/n_rows, 2)
            for id_predicate in self._cpa[id_col]:
                self._cpa[id_col][id_predicate] = round(self._cpa[id_col][id_predicate]/n_rows, 2)    
        
        
        for id_row, row in enumerate(self._data["candidates"]):
            for id_col, candidates in enumerate(row):
                id_col = str(id_col)
                for candidate in candidates:
                    (cta, ctaMax) = (0, 0)
                    for t in candidate["types"]:
                        if t["id"] in self._cta[id_col]:
                            cta += self._cta[id_col][t["id"]]
                            if self._cta[id_col][t["id"]] > ctaMax:
                                ctaMax = self._cta[id_col][t["id"]]
                    
                    (cpa, cpaMax) = (0, 0)
                    total_predicates = 0
                    for id_col_pred in candidate["predicates"]:
                        for id_predicate in candidate["predicates"][id_col_pred]:
                            if id_predicate in self._cpa[id_col]:
                                total_predicates += 1
                                cpa += self._cpa[id_col][id_predicate]
                                if self._cpa[id_col][id_predicate] > cpaMax:
                                    cpaMax = self._cpa[id_col][id_predicate]
                                
                    cta /= len(candidate["types"]) if len(candidate["types"]) > 0 else 1
                    candidate["features"]["cta"] = round(cta, 2)
                    candidate["features"]["ctaMax"] = ctaMax
                    
                    cpa /= total_predicates if total_predicates > 0 else 1
                    candidate["features"]["cpa"] = round(cpa, 2)
                    candidate["features"]["cpaMax"] = cpaMax

# %%
fe_revsion = FeaturesExtractionRevision(output)
fe_revsion.compute_features()
fe_revsion._cpa

# %%
len(output["features"][0])
# Out:
# 236

# %%
output["candidates"][0][0].sort(key=lambda x:x["features"]["cea"], reverse=True)

# %%
output["candidates"][3][3]
# Out:
# [{'id': 'Q434841',
#   'name': '20 Century Fox',
#   'descritpion': 'American film studio',
#   'types': [{'id': 'Q375336', 'name': 'film studio'},
#    {'id': 'Q1762059', 'name': 'film production company'},
#    {'id': 'Q10689397', 'name': 'television production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 82,
#    'pos_score': 0.01,
#    'es_score': 68.88,
#    'es_diff_score': 0.004774,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.946,
#    'p_obj_ne': 1.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.38,
#    'cpaMax': 0.5,
#    'cta': 0.58,
#    'ctaMax': 1.0,
#    'cea': 0.999,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P1128', 'o': '+2300', 's': 0.874},
#     {'p': 'P8687', 'o': '+4441100', 's': 0.001},
#     {'p': 'P8687', 'o': '+4202335', 's': 0.001},
#     {'p': 'P8687', 'o': '+199000', 's': 0.01},
#     {'p': 'P1128', 'o': '+2300', 's': 0.07},
#     {'p': 'P8687', 'o': '+199000', 's': 0.001},
#     {'p': 'P8687', 'o': '+4441100', 's': 0.002},
#     {'p': 'P8687', 'o': '+4202335', 's': 0.002},
#     {'p': 'P8687', 'o': '+4508574', 's': 0.002}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P1128': 0.874, 'P8687': 0.01},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q5476713',
#   'name': '21st Century Fox',
#   'descritpion': 'American multinational mass media corporation',
#   'types': [{'id': 'Q1331793', 'name': 'media company'},
#    {'id': 'Q219577', 'name': 'holding company'},
#    {'id': 'Q891723', 'name': 'public company'}],
#   'features': {'ntoken': 3,
#    'popularity': 40,
#    'pos_score': 0.35,
#    'es_score': 53.44,
#    'es_diff_score': 5.4e-05,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 1.327,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.25,
#    'cpaMax': 0.25,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.07,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P1128', 'o': '+25000', 's': 0.08},
#     {'p': 'P2137', 'o': '+19.564', 's': 0.01},
#     {'p': 'P2403', 'o': '+53.831', 's': 0.027},
#     {'p': 'P1128', 'o': '+25000', 's': 0.006},
#     {'p': 'P2137', 'o': '+19.564', 's': 0.121},
#     {'p': 'P2403', 'o': '+53.831', 's': 0.332},
#     {'p': 'P2226', 'o': '+27000000000', 's': 0.102},
#     {'p': 'P3362', 'o': '+5000000000', 's': 0.549},
#     {'p': 'P2295', 'o': '+3000000000', 's': 0.915}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P1128': 0.08,
#     'P2137': 0.121,
#     'P2403': 0.332,
#     'P2226': 0.102,
#     'P3362': 0.549,
#     'P2295': 0.915},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q5476713',
#   'name': 'Twenty-First Century Fox',
#   'descritpion': 'American multinational mass media corporation',
#   'types': [{'id': 'Q1331793', 'name': 'media company'},
#    {'id': 'Q219577', 'name': 'holding company'},
#    {'id': 'Q891723', 'name': 'public company'}],
#   'features': {'ntoken': 3,
#    'popularity': 40,
#    'pos_score': 0.05,
#    'es_score': 53.91,
#    'es_diff_score': 0.00142,
#    'ed_score': 0.5,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.82,
#    'p_subj_ne': 0,
#    'p_subj_lit': 1.327,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.25,
#    'cpaMax': 0.25,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.06,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P1128', 'o': '+25000', 's': 0.08},
#     {'p': 'P2137', 'o': '+19.564', 's': 0.01},
#     {'p': 'P2403', 'o': '+53.831', 's': 0.027},
#     {'p': 'P1128', 'o': '+25000', 's': 0.006},
#     {'p': 'P2137', 'o': '+19.564', 's': 0.121},
#     {'p': 'P2403', 'o': '+53.831', 's': 0.332},
#     {'p': 'P2226', 'o': '+27000000000', 's': 0.102},
#     {'p': 'P3362', 'o': '+5000000000', 's': 0.549},
#     {'p': 'P2295', 'o': '+3000000000', 's': 0.915}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P1128': 0.08,
#     'P2137': 0.121,
#     'P2403': 0.332,
#     'P2226': 0.102,
#     'P3362': 0.549,
#     'P2295': 0.915},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q166419',
#   'name': '20th Century Fox Television',
#   'descritpion': 'American television network',
#   'types': [{'id': 'Q1254874', 'name': 'television network'},
#    {'id': 'Q1616075', 'name': 'television station'},
#    {'id': 'Q10689397', 'name': 'television production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 81,
#    'pos_score': 0.94,
#    'es_score': 52.46,
#    'es_diff_score': 0.000162,
#    'ed_score': 0.52,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.002,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.5,
#    'cpaMax': 0.5,
#    'cta': 0.08,
#    'ctaMax': 0.25,
#    'cea': 0.06,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+1402820', 's': 0.001},
#     {'p': 'P8687', 'o': '+1397226', 's': 0.001},
#     {'p': 'P8687', 'o': '+1435467', 's': 0.001},
#     {'p': 'P8687', 'o': '+1402820', 's': 0.001},
#     {'p': 'P8687', 'o': '+1397226', 's': 0.001},
#     {'p': 'P8687', 'o': '+1435467', 's': 0.001}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.001},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q73622',
#   'name': '30th Century Fox',
#   'descritpion': 'American animated sitcom for the Fox Broadcasting Company and Comedy Central',
#   'types': [{'id': 'Q581714', 'name': 'animated series'}],
#   'features': {'ntoken': 3,
#    'popularity': 76,
#    'pos_score': 0.22,
#    'es_score': 53.57,
#    'es_diff_score': 0.000273,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.85,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.9339999999999999,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.04,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P1113', 'o': '+140', 's': 0.07},
#     {'p': 'P2437', 'o': '+7', 's': 0.004},
#     {'p': 'P2047', 'o': '+22', 's': 0.011},
#     {'p': 'P1113', 'o': '+140', 's': 0.864},
#     {'p': 'P2437', 'o': '+7', 's': 0.043},
#     {'p': 'P2047', 'o': '+22', 's': 0.136}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P1113': 0.864, 'P2437': 0.043, 'P2047': 0.136},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Kateqoriya:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.11,
#    'es_score': 53.73,
#    'es_diff_score': 0.000623,
#    'ed_score': 0.52,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.32,
#    'cosine_similarity': 0.78,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.013,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q201949',
#   'name': 'Twentieth Century Fox (song)',
#   'descritpion': '1967 self-titled debut studio album by The Doors',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'features': {'ntoken': 3,
#    'popularity': 53,
#    'pos_score': 0.49,
#    'es_score': 52.88,
#    'es_diff_score': 0.000708,
#    'ed_score': 0.43,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.69,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.8520000000000001,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.013,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P2047', 'o': '+2548', 's': 0.788},
#     {'p': 'P2635', 'o': '+6', 's': 0.003},
#     {'p': 'P2635', 'o': '+5', 's': 0.003},
#     {'p': 'P2047', 'o': '+2548', 's': 0.064},
#     {'p': 'P2635', 'o': '+6', 's': 0.037},
#     {'p': 'P2635', 'o': '+5', 's': 0.031}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P2047': 0.788, 'P2635': 0.037},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Категория:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.12,
#    'es_score': 53.69,
#    'es_diff_score': 5.2e-05,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.77,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.012,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Kategori:Film 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.76,
#    'es_score': 52.59,
#    'es_diff_score': 0.000163,
#    'ed_score': 0.47,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.32,
#    'cosine_similarity': 0.73,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.012,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Categoria:Film 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.79,
#    'es_score': 52.57,
#    'es_diff_score': 8.6e-05,
#    'ed_score': 0.45,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.3,
#    'cosine_similarity': 0.76,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.012,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Categorie:Filme 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.81,
#    'es_score': 52.56,
#    'es_diff_score': 0.000206,
#    'ed_score': 0.44,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.29,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.012,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Катэгорыя:Фільмы 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.61,
#    'es_score': 52.74,
#    'es_diff_score': 0.000142,
#    'ed_score': 0.42,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.27,
#    'cosine_similarity': 0.76,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.011,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Category:20th Century Fox films',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.64,
#    'es_score': 52.71,
#    'es_diff_score': 7.2e-05,
#    'ed_score': 0.45,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.3,
#    'cosine_similarity': 0.73,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.011,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Kategori:Filem 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.83,
#    'es_score': 52.54,
#    'es_diff_score': 2.8e-05,
#    'ed_score': 0.45,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.3,
#    'cosine_similarity': 0.76,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.011,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Category:20th Century Fox movies',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.84,
#    'es_score': 52.53,
#    'es_diff_score': 0.0,
#    'ed_score': 0.44,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.29,
#    'cosine_similarity': 0.73,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.01,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Категория:Фильмы 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.85,
#    'es_score': 52.53,
#    'es_diff_score': 0.000112,
#    'ed_score': 0.42,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.27,
#    'cosine_similarity': 0.75,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.01,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Categoría:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.14,
#    'es_score': 53.66,
#    'es_diff_score': 0.000157,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.009,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Kategorija:20th Century Fox filmas',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.6,
#    'es_score': 52.74,
#    'es_diff_score': 4.7e-05,
#    'ed_score': 0.41,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.26,
#    'cosine_similarity': 0.68,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.009,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Санат:20th Century Fox фильмдері',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.91,
#    'es_score': 52.48,
#    'es_diff_score': 0.000153,
#    'ed_score': 0.44,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.29,
#    'cosine_similarity': 0.71,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.009,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Kategória:Filmy 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.95,
#    'es_score': 52.46,
#    'es_diff_score': 6e-05,
#    'ed_score': 0.44,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.29,
#    'cosine_similarity': 0.67,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.008,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Категорія:Фільми 20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.96,
#    'es_score': 52.45,
#    'es_diff_score': 0.0,
#    'ed_score': 0.42,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.27,
#    'cosine_similarity': 0.74,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.008,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6430049',
#   'name': 'Կատեգորիա:20th Century Fox ֆիլմեր',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 63,
#    'pos_score': 0.97,
#    'es_score': 52.45,
#    'es_diff_score': 0.000792,
#    'ed_score': 0.42,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.27,
#    'cosine_similarity': 0.7,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.007,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Catégorie:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.18,
#    'es_score': 53.6,
#    'es_diff_score': 3.3e-05,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.73,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.006,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Categori:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.2,
#    'es_score': 53.58,
#    'es_diff_score': 0.000155,
#    'ed_score': 0.56,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.8,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.006,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Category:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.23,
#    'es_score': 53.55,
#    'es_diff_score': 4e-06,
#    'ed_score': 0.56,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.82,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.006,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Санат:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.27,
#    'es_score': 53.52,
#    'es_diff_score': 0.0,
#    'ed_score': 0.64,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.43,
#    'cosine_similarity': 0.87,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.006,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Катэгорыя:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.21,
#    'es_score': 53.57,
#    'es_diff_score': 5.6e-05,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.75,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.005,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Категорія:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.24,
#    'es_score': 53.55,
#    'es_diff_score': 0.000158,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.78,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.005,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Kategoria:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.28,
#    'es_score': 53.52,
#    'es_diff_score': 0.0,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.8,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.005,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Categorie:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.29,
#    'es_score': 53.52,
#    'es_diff_score': 0.000359,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.85,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.005,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Kategorio:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.32,
#    'es_score': 53.47,
#    'es_diff_score': 3e-06,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.77,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Kategory:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.36,
#    'es_score': 53.44,
#    'es_diff_score': 0.0001,
#    'ed_score': 0.56,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Kategori:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.37,
#    'es_score': 53.43,
#    'es_diff_score': 0.000105,
#    'ed_score': 0.56,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'კატეგორია:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.39,
#    'es_score': 53.42,
#    'es_diff_score': 0.000912,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.8,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Categoria:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.42,
#    'es_score': 53.28,
#    'es_diff_score': 0.001758,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.81,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q22348727',
#   'name': '20th Century Fox',
#   'descritpion': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'features': {'ntoken': 3,
#    'popularity': 4,
#    'pos_score': 0.52,
#    'es_score': 52.81,
#    'es_diff_score': 5.2e-05,
#    'ed_score': 0.88,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.87,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.5,
#    'ctaMax': 0.5,
#    'cea': 0.003,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2644123',
#   'name': '20th Century Fox',
#   'descritpion': 'American film production company',
#   'types': [{'id': 'Q1762059', 'name': 'film production company'},
#    {'id': 'Q375336', 'name': 'film studio'}],
#   'features': {'ntoken': 3,
#    'popularity': 21,
#    'pos_score': 0.38,
#    'es_score': 53.43,
#    'es_diff_score': 4.8e-05,
#    'ed_score': 0.88,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.87,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.75,
#    'ctaMax': 1.0,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6812796',
#   'name': '21st Century Fox',
#   'descritpion': 'Canadian professional wrestler',
#   'types': [{'id': 'Q5', 'name': 'human'},
#    {'id': 'Q13474373', 'name': 'professional wrestler'}],
#   'features': {'ntoken': 3,
#    'popularity': 2,
#    'pos_score': 0.51,
#    'es_score': 52.83,
#    'es_diff_score': 0.000299,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4631062',
#   'name': '21st Century Fox',
#   'descritpion': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'features': {'ntoken': 3,
#    'popularity': 3,
#    'pos_score': 0.53,
#    'es_score': 52.81,
#    'es_diff_score': 0.000115,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.5,
#    'ctaMax': 0.5,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4631065',
#   'name': '21st Century Fox',
#   'descritpion': 'album of British model-turned-singer Samantha Fox',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'features': {'ntoken': 3,
#    'popularity': 3,
#    'pos_score': 0.55,
#    'es_score': 52.79,
#    'es_diff_score': 0.000526,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6970155',
#   'name': 'Thể loại:20th Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 39,
#    'pos_score': 0.69,
#    'es_score': 52.67,
#    'es_diff_score': 1.2e-05,
#    'ed_score': 0.56,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.43,
#    'cosine_similarity': 0.8,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q885885',
#   'name': '20th Century Fox Animation',
#   'descritpion': 'American computer animation film studio',
#   'types': [{'id': 'Q1107679', 'name': 'animation studio'},
#    {'id': 'Q1762059', 'name': 'film production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 40,
#    'pos_score': 0.7,
#    'es_score': 52.67,
#    'es_diff_score': 0.000577,
#    'ed_score': 0.54,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.07100000000000001,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.5,
#    'cpaMax': 0.5,
#    'cta': 0.75,
#    'ctaMax': 1.0,
#    'cea': 0.002,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+31916', 's': 0.063},
#     {'p': 'P8687', 'o': '+30559', 's': 0.066},
#     {'p': 'P8687', 'o': '+33826', 's': 0.059},
#     {'p': 'P8687', 'o': '+31916', 's': 0.005},
#     {'p': 'P8687', 'o': '+30559', 's': 0.005},
#     {'p': 'P8687', 'o': '+33826', 's': 0.005}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.066},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q15137099',
#   'name': 'Categoria:21st Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 21,
#    'pos_score': 0.19,
#    'es_score': 53.6,
#    'es_diff_score': 0.000434,
#    'ed_score': 0.5,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.33,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q15137099',
#   'name': 'Kategori:21st Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 21,
#    'pos_score': 0.33,
#    'es_score': 53.47,
#    'es_diff_score': 0.000131,
#    'ed_score': 0.52,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.78,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q15137099',
#   'name': 'Category:21st Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 21,
#    'pos_score': 0.43,
#    'es_score': 53.19,
#    'es_diff_score': 0.0,
#    'ed_score': 0.52,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.74,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4030862',
#   'name': '31st Century Fox',
#   'descritpion': 'episode of Futurama',
#   'types': [{'id': 'Q21191270', 'name': 'television series episode'}],
#   'features': {'ntoken': 3,
#    'popularity': 5,
#    'pos_score': 0.45,
#    'es_score': 53.02,
#    'es_diff_score': 0.000887,
#    'ed_score': 0.75,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.86,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q7857704',
#   'name': 'Twentieth Century Fox',
#   'descritpion': 'song performed by The Doors',
#   'types': [{'id': 'Q105543609', 'name': 'musical work/composition'}],
#   'features': {'ntoken': 3,
#    'popularity': 3,
#    'pos_score': 0.48,
#    'es_score': 52.91,
#    'es_diff_score': 0.000636,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.81,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q111139958',
#   'name': 'Template:20th Century Fox',
#   'descritpion': '',
#   'types': [],
#   'features': {'ntoken': 3,
#    'popularity': 4,
#    'pos_score': 0.72,
#    'es_score': 52.63,
#    'es_diff_score': 0.000154,
#    'ed_score': 0.56,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.85,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q634019',
#   'name': '20th Century Fox Animation',
#   'descritpion': 'American animation studio',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 15,
#    'pos_score': 0.86,
#    'es_score': 52.53,
#    'es_diff_score': 3.7e-05,
#    'ed_score': 0.54,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2814799',
#   'name': '20th Century Fox Television',
#   'descritpion': 'American television production company',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'},
#    {'id': 'Q658255', 'name': 'subsidiary'}],
#   'features': {'ntoken': 3,
#    'popularity': 17,
#    'pos_score': 0.87,
#    'es_score': 52.53,
#    'es_diff_score': 0.000241,
#    'ed_score': 0.52,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.12,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2814799',
#   'name': '20th Century Fox TV',
#   'descritpion': 'American television production company',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'},
#    {'id': 'Q658255', 'name': 'subsidiary'}],
#   'features': {'ntoken': 3,
#    'popularity': 17,
#    'pos_score': 0.88,
#    'es_score': 52.51,
#    'es_diff_score': 3.8e-05,
#    'ed_score': 0.74,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.76,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.12,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q76348327',
#   'name': '21st Century Fox',
#   'descritpion': 'print in the National Gallery of Art (NGA 123124)',
#   'types': [{'id': 'Q11060274', 'name': 'print'}],
#   'features': {'ntoken': 3,
#    'popularity': 1,
#    'pos_score': 0.89,
#    'es_score': 52.51,
#    'es_diff_score': 7.6e-05,
#    'ed_score': 0.81,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.75,
#    'cosine_similarity': 0.79,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.506,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P2048', 'o': '+75.88', 's': 0.038},
#     {'p': 'P2049', 'o': '+55.56', 's': 0.028},
#     {'p': 'P2048', 'o': '+75.88', 's': 0.468},
#     {'p': 'P2049', 'o': '+55.56', 's': 0.343}],
#    '4': [],
#    '5': []},
#   'predicates': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P2048': 0.468, 'P2049': 0.343},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q15137099',
#   'name': 'Thể loại:21st Century Fox',
#   'descritpion': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'features': {'ntoken': 3,
#    'popularity': 21,
#    'pos_score': 0.9,
#    'es_score': 52.51,
#    'es_diff_score': 0.000493,
#    'ed_score': 0.52,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.43,
#    'cosine_similarity': 0.77,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2264873',
#   'name': '20th Century Fox Games',
#   'descritpion': 'former subsidiary of Vivendi S.A. and holdings company for Sierra Entertainment and Blizzard Entertainment',
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q210167', 'name': 'video game developer'}],
#   'features': {'ntoken': 3,
#    'popularity': 17,
#    'pos_score': 0.93,
#    'es_score': 52.47,
#    'es_diff_score': 0.000114,
#    'ed_score': 0.64,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.55,
#    'cosine_similarity': 0.76,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.5,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2814799',
#   'name': '20th Century FOX Television',
#   'descritpion': 'American television production company',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'},
#    {'id': 'Q658255', 'name': 'subsidiary'}],
#   'features': {'ntoken': 3,
#    'popularity': 17,
#    'pos_score': 0.98,
#    'es_score': 52.41,
#    'es_diff_score': 0.001433,
#    'ed_score': 0.52,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.12,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2084961',
#   'name': '20th Century Fox Video',
#   'descritpion': 'American home video distributor',
#   'types': [{'id': 'Q4830453', 'name': 'business'}],
#   'features': {'ntoken': 3,
#    'popularity': 13,
#    'pos_score': 0.99,
#    'es_score': 52.34,
#    'es_diff_score': 0.000363,
#    'ed_score': 0.64,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.55,
#    'cosine_similarity': 0.74,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.5,
#    'ctaMax': 0.5,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2717612',
#   'name': '20th Century Fox Television',
#   'descritpion': 'TV production company - redirects to 20th Television',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 15,
#    'pos_score': 1.0,
#    'es_score': 52.32,
#    'es_diff_score': 0,
#    'ed_score': 0.52,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.72,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q15138624',
#   'name': 'Template:21st Century Fox',
#   'descritpion': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'features': {'ntoken': 3,
#    'popularity': 9,
#    'pos_score': 0.4,
#    'es_score': 53.38,
#    'es_diff_score': 0.000687,
#    'ed_score': 0.52,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.35,
#    'cosine_similarity': 0.8,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q15138624',
#   'name': 'Templat:21st Century Fox',
#   'descritpion': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'features': {'ntoken': 3,
#    'popularity': 9,
#    'pos_score': 0.47,
#    'es_score': 52.96,
#    'es_diff_score': 0.001021,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.38,
#    'cosine_similarity': 0.7,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2814799',
#   'name': 'Twentieth Century Fox Television',
#   'descritpion': 'American television production company',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'},
#    {'id': 'Q658255', 'name': 'subsidiary'}],
#   'features': {'ntoken': 3,
#    'popularity': 17,
#    'pos_score': 0.5,
#    'es_score': 52.84,
#    'es_diff_score': 0.000206,
#    'ed_score': 0.38,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.3,
#    'cosine_similarity': 0.68,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.12,
#    'ctaMax': 0.25,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2717612',
#   'name': 'Twentieth Century Fox Television',
#   'descritpion': 'TV production company - redirects to 20th Television',
#   'types': [{'id': 'Q10689397', 'name': 'television production company'}],
#   'features': {'ntoken': 3,
#    'popularity': 15,
#    'pos_score': 0.67,
#    'es_score': 52.68,
#    'es_diff_score': 0.000124,
#    'ed_score': 0.38,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.3,
#    'cosine_similarity': 0.68,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0.0,
#    'cpaMax': 0,
#    'cta': 0.25,
#    'ctaMax': 0.25,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'predicates': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}}]

# %%
output["candidates"][3][0]
# Out:
# [{'id': 'Q24871',
#   'name': 'Avatar',
#   'descritpion': '2009 American epic science fiction film directed by James Cameron',
#   'types': [{'id': 'Q229390', 'name': '3D film'},
#    {'id': 'Q25110269', 'name': 'live-action/animated film'}],
#   'features': {'ntoken': 1,
#    'popularity': 117,
#    'pos_score': 0.09,
#    'es_score': 36.17,
#    'es_diff_score': 0.000959,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 2.0,
#    'p_subj_lit': 2.081,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.996,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P57', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P162', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P58', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P1040', 'o': 'Q42574', 's': 1.0}],
#    '2': [],
#    '3': [{'p': 'P272', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P2047', 'o': '+162', 's': 0.081},
#     {'p': 'P8687', 'o': '+148542', 's': 0.013},
#     {'p': 'P8687', 'o': '+41801', 's': 0.048},
#     {'p': 'P8687', 'o': '+51600', 's': 0.039},
#     {'p': 'P8687', 'o': '+162471', 's': 0.012},
#     {'p': 'P8687', 'o': '+56800', 's': 0.035},
#     {'p': 'P2047', 'o': '+162', 's': 1.0},
#     {'p': 'P8687', 'o': '+148542', 's': 0.001},
#     {'p': 'P8687', 'o': '+41801', 's': 0.004},
#     {'p': 'P8687', 'o': '+51600', 's': 0.003},
#     {'p': 'P8687', 'o': '+162471', 's': 0.001},
#     {'p': 'P8687', 'o': '+56800', 's': 0.003},
#     {'p': 'P2130', 'o': '+237000000', 's': 0.086},
#     {'p': 'P2142', 'o': '+2744336793', 's': 1.0},
#     {'p': 'P2142', 'o': '+760507625', 's': 0.277},
#     {'p': 'P2142', 'o': '+93442625', 's': 0.034}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {'P57': 1.0, 'P162': 1.0, 'P58': 1.0, 'P1040': 1.0},
#    '2': {},
#    '3': {'P272': 1.0,
#     'P2047': 1.0,
#     'P8687': 0.048,
#     'P2130': 0.086,
#     'P2142': 1.0},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q83090',
#   'name': 'Avatar',
#   'descritpion': 'material appearance or incarnation of a deity on earth in Hinduism',
#   'types': [{'id': 'Q23847174', 'name': 'religious concept'}],
#   'features': {'ntoken': 1,
#    'popularity': 82,
#    'pos_score': 0.01,
#    'es_score': 36.81,
#    'es_diff_score': 0.001376,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.958,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q128593',
#   'name': 'Avatar',
#   'descritpion': 'concept of rebirth in some religions and cultures',
#   'types': [{'id': 'Q23847174', 'name': 'religious concept'},
#    {'id': 'Q1047698', 'name': 'superpower'}],
#   'features': {'ntoken': 1,
#    'popularity': 90,
#    'pos_score': 0.06,
#    'es_score': 36.34,
#    'es_diff_score': 0.001151,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.556,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q11572',
#   'name': 'Avatar',
#   'descritpion': 'animated television series',
#   'types': [{'id': 'Q581714', 'name': 'animated series'},
#    {'id': 'Q5398426', 'name': 'television series'}],
#   'features': {'ntoken': 1,
#    'popularity': 70,
#    'pos_score': 0.12,
#    'es_score': 36.04,
#    'es_diff_score': 0.001542,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.40700000000000003,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.457,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P2437', 'o': '+3', 's': 0.002},
#     {'p': 'P1113', 'o': '+61', 's': 0.03},
#     {'p': 'P2047', 'o': '+23', 's': 0.011},
#     {'p': 'P2437', 'o': '+3', 's': 0.018},
#     {'p': 'P1113', 'o': '+61', 's': 0.377},
#     {'p': 'P2047', 'o': '+23', 's': 0.142}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P2437': 0.018, 'P1113': 0.377, 'P2047': 0.142},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q86060153',
#   'name': 'Avatar',
#   'descritpion': 'oil products tanker built in 2007',
#   'types': [{'id': 'Q11446', 'name': 'ship'}],
#   'features': {'ntoken': 1,
#    'popularity': 1,
#    'pos_score': 1.0,
#    'es_score': 35.14,
#    'es_diff_score': 0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 1.02,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.362,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P4519', 'o': '+6876', 's': 0.292},
#     {'p': 'P2043', 'o': '+99.8', 's': 0.05},
#     {'p': 'P2049', 'o': '+18', 's': 0.009},
#     {'p': 'P1093', 'o': '+4969', 's': 0.404},
#     {'p': 'P4519', 'o': '+6876', 's': 0.024},
#     {'p': 'P2043', 'o': '+99.8', 's': 0.616},
#     {'p': 'P2049', 'o': '+18', 's': 0.111},
#     {'p': 'P1093', 'o': '+4969', 's': 0.033}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P4519': 0.292, 'P2043': 0.616, 'P2049': 0.111, 'P1093': 0.404},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q152402',
#   'name': 'Avatar',
#   'descritpion': "graphical representation of the user or the user's alter ego or character",
#   'types': [],
#   'features': {'ntoken': 1,
#    'popularity': 44,
#    'pos_score': 0.02,
#    'es_score': 36.76,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.347,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q192172',
#   'name': 'Avatar',
#   'descritpion': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'features': {'ntoken': 1,
#    'popularity': 50,
#    'pos_score': 0.07,
#    'es_score': 36.29,
#    'es_diff_score': 0.000595,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.271,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q3604746',
#   'name': 'AVATAR 2',
#   'descritpion': 'James Cameron film scheduled for 2022',
#   'types': [{'id': 'Q18011172', 'name': 'film project'},
#    {'id': 'Q261636', 'name': 'sequel'}],
#   'features': {'ntoken': 1,
#    'popularity': 35,
#    'pos_score': 0.49,
#    'es_score': 35.52,
#    'es_diff_score': 8.3e-05,
#    'ed_score': 0.75,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.26,
#    'p_subj_ne': 2.0,
#    'p_subj_lit': 0.091,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.198,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P57', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P58', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P162', 'o': 'Q42574', 's': 1.0}],
#    '2': [],
#    '3': [{'p': 'P272', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P750', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P2130', 'o': '+250000000', 's': 0.091}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {'P57': 1.0, 'P58': 1.0, 'P162': 1.0},
#    '2': {},
#    '3': {'P272': 1.0, 'P750': 1.0, 'P2130': 0.091},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q3604746',
#   'name': 'Avatar 2',
#   'descritpion': 'James Cameron film scheduled for 2022',
#   'types': [{'id': 'Q18011172', 'name': 'film project'},
#    {'id': 'Q261636', 'name': 'sequel'}],
#   'features': {'ntoken': 1,
#    'popularity': 35,
#    'pos_score': 0.5,
#    'es_score': 35.52,
#    'es_diff_score': 0.00165,
#    'ed_score': 0.75,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.26,
#    'p_subj_ne': 2.0,
#    'p_subj_lit': 0.091,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.192,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P57', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P58', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P162', 'o': 'Q42574', 's': 1.0}],
#    '2': [],
#    '3': [{'p': 'P272', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P750', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P2130', 'o': '+250000000', 's': 0.091}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {'P57': 1.0, 'P58': 1.0, 'P162': 1.0},
#    '2': {},
#    '3': {'P272': 1.0, 'P750': 1.0, 'P2130': 0.091},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q1462437',
#   'name': 'Avatar',
#   'descritpion': 'video game',
#   'types': [{'id': 'Q7889', 'name': 'video game'}],
#   'features': {'ntoken': 1,
#    'popularity': 17,
#    'pos_score': 0.38,
#    'es_score': 35.6,
#    'es_diff_score': 6e-05,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0.65,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.157,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P144', 'o': 'Q24871', 's': 0.65}],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': []},
#   'pred': {'0': {}, '1': {'P144': 0.65}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q73966879',
#   'name': 'Avatar',
#   'descritpion': 'American science-fiction film media franchise',
#   'types': [{'id': 'Q196600', 'name': 'media franchise'}],
#   'features': {'ntoken': 1,
#    'popularity': 7,
#    'pos_score': 0.17,
#    'es_score': 35.92,
#    'es_diff_score': 3.2e-05,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0.65,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.147,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P527', 'o': 'Q24871', 's': 0.65}],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': []},
#   'pred': {'0': {}, '1': {'P527': 0.65}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q3604746',
#   'name': 'Avatar II',
#   'descritpion': 'James Cameron film scheduled for 2022',
#   'types': [{'id': 'Q18011172', 'name': 'film project'},
#    {'id': 'Q261636', 'name': 'sequel'}],
#   'features': {'ntoken': 1,
#    'popularity': 35,
#    'pos_score': 0.18,
#    'es_score': 35.92,
#    'es_diff_score': 0.000182,
#    'ed_score': 0.67,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.11,
#    'p_subj_ne': 2.0,
#    'p_subj_lit': 0.091,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.144,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P57', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P58', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P162', 'o': 'Q42574', 's': 1.0}],
#    '2': [],
#    '3': [{'p': 'P272', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P750', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P2130', 'o': '+250000000', 's': 0.091}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {'P57': 1.0, 'P58': 1.0, 'P162': 1.0},
#    '2': {},
#    '3': {'P272': 1.0, 'P750': 1.0, 'P2130': 0.091},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q790261',
#   'name': 'Avatar',
#   'descritpion': 'Swedish melodic death metal band',
#   'types': [{'id': 'Q215380', 'name': 'musical group'}],
#   'features': {'ntoken': 1,
#    'popularity': 19,
#    'pos_score': 0.05,
#    'es_score': 36.63,
#    'es_diff_score': 0.008134,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.085,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.092,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+25345', 's': 0.079},
#     {'p': 'P8687', 'o': '+280000', 's': 0.007},
#     {'p': 'P8687', 'o': '+27782', 's': 0.072},
#     {'p': 'P8687', 'o': '+25345', 's': 0.006},
#     {'p': 'P8687', 'o': '+280000', 's': 0.001},
#     {'p': 'P8687', 'o': '+27782', 's': 0.006}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.079},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q29580929',
#   'name': 'Avatar 3',
#   'descritpion': '2024 American -fi action film by James Cameron',
#   'types': [{'id': 'Q18011172', 'name': 'film project'},
#    {'id': 'Q261636', 'name': 'sequel'}],
#   'features': {'ntoken': 1,
#    'popularity': 21,
#    'pos_score': 0.22,
#    'es_score': 35.83,
#    'es_diff_score': 0.001131,
#    'ed_score': 0.75,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.24,
#    'p_subj_ne': 2.0,
#    'p_subj_lit': 0.091,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.073,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P57', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P162', 'o': 'Q42574', 's': 1.0},
#     {'p': 'P58', 'o': 'Q42574', 's': 1.0}],
#    '2': [],
#    '3': [{'p': 'P272', 'o': 'Q434841', 's': 1.0},
#     {'p': 'P2130', 'o': '+250000000', 's': 0.091}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {'P57': 1.0, 'P162': 1.0, 'P58': 1.0},
#    '2': {},
#    '3': {'P272': 1.0, 'P2130': 0.091},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q29387886',
#   'name': 'Avatar',
#   'descritpion': 'planned series of five science-fiction films',
#   'types': [{'id': 'Q24856', 'name': 'film series'}],
#   'features': {'ntoken': 1,
#    'popularity': 3,
#    'pos_score': 0.47,
#    'es_score': 35.53,
#    'es_diff_score': 0.000268,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0.65,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.061,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P527', 'o': 'Q24871', 's': 0.65}],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': []},
#   'pred': {'0': {}, '1': {'P527': 0.65}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2624716',
#   'name': 'Avatar',
#   'descritpion': 'fictional character in Marvel Comics',
#   'types': [{'id': 'Q15632617', 'name': 'fictional human'},
#    {'id': 'Q1094617', 'name': 'mutant'},
#    {'id': 'Q48282', 'name': 'student'},
#    {'id': 'Q188784', 'name': 'superhero'}],
#   'features': {'ntoken': 1,
#    'popularity': 11,
#    'pos_score': 0.1,
#    'es_score': 36.14,
#    'es_diff_score': 0.002137,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.029,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827783',
#   'name': 'Avatar',
#   'descritpion': 'village in Iran',
#   'types': [{'id': 'Q532', 'name': 'village'}],
#   'features': {'ntoken': 1,
#    'popularity': 5,
#    'pos_score': 0.54,
#    'es_score': 35.43,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.028,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q16010853',
#   'name': 'Avatar',
#   'descritpion': '19th century short story by French writer Théophile Gautier',
#   'types': [{'id': 'Q7725634', 'name': 'literary work'}],
#   'features': {'ntoken': 1,
#    'popularity': 5,
#    'pos_score': 0.55,
#    'es_score': 35.43,
#    'es_diff_score': 1e-06,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.028,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4055418',
#   'name': 'Avatar',
#   'descritpion': '2004 Singaporean sci-fi film directed by Kuo Jian Hong',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'features': {'ntoken': 1,
#    'popularity': 6,
#    'pos_score': 0.08,
#    'es_score': 36.27,
#    'es_diff_score': 0.002719,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.027,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2536755',
#   'name': 'Avatar',
#   'descritpion': 'Title character of The Legend of Korra animated television series',
#   'types': [{'id': 'Q15711870', 'name': 'animated character'},
#    {'id': 'Q15632617', 'name': 'fictional human'},
#    {'id': 'Q15773317', 'name': 'television character'}],
#   'features': {'ntoken': 1,
#    'popularity': 12,
#    'pos_score': 0.15,
#    'es_score': 35.92,
#    'es_diff_score': 0.000155,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.027,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q3630994',
#   'name': 'Avatar',
#   'descritpion': '1916 film',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'features': {'ntoken': 1,
#    'popularity': 7,
#    'pos_score': 0.13,
#    'es_score': 35.98,
#    'es_diff_score': 0.000938,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.026,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q9290845',
#   'name': 'Avatar',
#   'descritpion': 'Ultima series of video games',
#   'types': [{'id': 'Q95074', 'name': 'fictional character'}],
#   'features': {'ntoken': 1,
#    'popularity': 4,
#    'pos_score': 0.35,
#    'es_score': 35.62,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.025,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827801',
#   'name': 'Avatar',
#   'descritpion': 'representation of users of the Xbox Live service',
#   'types': [{'id': 'Q235557', 'name': 'file format'}],
#   'features': {'ntoken': 1,
#    'popularity': 4,
#    'pos_score': 0.36,
#    'es_score': 35.62,
#    'es_diff_score': 0.000193,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.025,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q20731500',
#   'name': 'Avatar',
#   'descritpion': '',
#   'types': [{'id': 'Q11446', 'name': 'ship'}],
#   'features': {'ntoken': 1,
#    'popularity': 3,
#    'pos_score': 0.7,
#    'es_score': 35.36,
#    'es_diff_score': 0.000128,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.025,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2689187',
#   'name': 'Avatar',
#   'descritpion': 'fictional group of beings in Charmed',
#   'types': [{'id': 'Q14514600', 'name': 'group of fictional characters'}],
#   'features': {'ntoken': 1,
#    'popularity': 4,
#    'pos_score': 0.14,
#    'es_score': 35.95,
#    'es_diff_score': 0.000735,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.024,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827794',
#   'name': 'Avatar',
#   'descritpion': 'episode of The X-Files (S3 E21)',
#   'types': [{'id': 'Q21191270', 'name': 'television series episode'}],
#   'features': {'ntoken': 1,
#    'popularity': 7,
#    'pos_score': 0.21,
#    'es_score': 35.86,
#    'es_diff_score': 0.000693,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.024,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4034632',
#   'name': 'Avatar',
#   'descritpion': '2009 Avatar studio album',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'features': {'ntoken': 1,
#    'popularity': 6,
#    'pos_score': 0.23,
#    'es_score': 35.79,
#    'es_diff_score': 0.000105,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.024,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827793',
#   'name': 'Avatar',
#   'descritpion': 'album by psychedelic indie rock band Comets on Fire',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'features': {'ntoken': 1,
#    'popularity': 3,
#    'pos_score': 0.39,
#    'es_score': 35.6,
#    'es_diff_score': 0.000223,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.023,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q19730903',
#   'name': 'Avatar',
#   'descritpion': 'Indian concept for a manned single-stage reusable spaceplane',
#   'types': [{'id': 'Q1298668', 'name': 'research project'}],
#   'features': {'ntoken': 1,
#    'popularity': 9,
#    'pos_score': 0.29,
#    'es_score': 35.71,
#    'es_diff_score': 0.001464,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.022,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827791',
#   'name': 'Avatar',
#   'descritpion': 'novel by John Passarella',
#   'types': [{'id': 'Q7725634', 'name': 'literary work'}],
#   'features': {'ntoken': 1,
#    'popularity': 3,
#    'pos_score': 0.33,
#    'es_score': 35.66,
#    'es_diff_score': 0.000564,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.022,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q103290917',
#   'name': 'Avatar',
#   'descritpion': '',
#   'types': [{'id': 'Q11446', 'name': 'ship'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.83,
#    'es_score': 35.27,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.7320000000000001,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.022,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P1093', 'o': '+2966', 's': 0.677},
#     {'p': 'P1093', 'o': '+2966', 's': 0.055}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P1093': 0.677},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q5713126',
#   'name': 'Avatar',
#   'descritpion': 'episode of Stargate SG-1 (S8 E6)',
#   'types': [{'id': 'Q21191270', 'name': 'television series episode'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.84,
#    'es_score': 35.27,
#    'es_diff_score': 1.7e-05,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.022,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q17695679',
#   'name': 'Avatar',
#   'descritpion': 'Wikinews article',
#   'types': [{'id': 'Q17633526', 'name': 'Wikinews article'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.85,
#    'es_score': 35.27,
#    'es_diff_score': 0.000132,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.022,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q17014504',
#   'name': 'AVATAR',
#   'descritpion': '1991 video game',
#   'types': [{'id': 'Q7889', 'name': 'video game'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.52,
#    'es_score': 35.45,
#    'es_diff_score': 0.000537,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.021,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827800',
#   'name': 'Avatar',
#   'descritpion': 'American underground newspaper published in Boston',
#   'types': [{'id': 'Q11032', 'name': 'newspaper'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.63,
#    'es_score': 35.39,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.021,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q65321559',
#   'name': 'Avatar',
#   'descritpion': '',
#   'types': [],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.64,
#    'es_score': 35.39,
#    'es_diff_score': 0.000329,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.021,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827790',
#   'name': 'Avatar',
#   'descritpion': 'album by the Dutch futurepop band Angels and Agony',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.26,
#    'es_score': 35.75,
#    'es_diff_score': 5e-06,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.02,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4686327',
#   'name': 'AVATAR',
#   'descritpion': 'system of escape sequences occasionally used on bulletin board systems',
#   'types': [{'id': 'Q184759', 'name': 'character encoding'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.27,
#    'es_score': 35.75,
#    'es_diff_score': 0.0,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.02,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827797',
#   'name': 'Avatar',
#   'descritpion': 'American Thoroughbred racehorse',
#   'types': [{'id': 'Q726', 'name': 'horse'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.28,
#    'es_score': 35.75,
#    'es_diff_score': 0.000939,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.02,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q20446053',
#   'name': 'Avatar',
#   'descritpion': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'features': {'ntoken': 1,
#    'popularity': 2,
#    'pos_score': 0.97,
#    'es_score': 35.15,
#    'es_diff_score': 0.000184,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.02,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q316939',
#   'name': 'Avatar language',
#   'descritpion': 'constructed language',
#   'types': [{'id': 'Q2623733', 'name': 'fictional language'},
#    {'id': 'Q33215', 'name': 'constructed language'}],
#   'features': {'ntoken': 1,
#    'popularity': 45,
#    'pos_score': 0.44,
#    'es_score': 35.57,
#    'es_diff_score': 0.000333,
#    'ed_score': 0.4,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.15,
#    'p_subj_ne': 0.65,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.004,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P1441', 'o': 'Q24871', 's': 0.65}],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': []},
#   'pred': {'0': {}, '1': {'P1441': 0.65}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q517977',
#   'name': 'Varaha avatar',
#   'descritpion': 'boar avatar of Vishnu',
#   'types': [{'id': 'Q83090', 'name': 'avatar'}],
#   'features': {'ntoken': 1,
#    'popularity': 45,
#    'pos_score': 0.25,
#    'es_score': 35.79,
#    'es_diff_score': 0.001156,
#    'ed_score': 0.46,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.11,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q1640011',
#   'name': 'Avatar Aang',
#   'descritpion': 'title character of Avatar: The Last Airbender',
#   'types': [{'id': 'Q15632617', 'name': 'fictional human'},
#    {'id': 'Q15711870', 'name': 'animated character'},
#    {'id': 'Q15773347', 'name': 'film character'},
#    {'id': 'Q1114461', 'name': 'comics character'},
#    {'id': 'Q15773317', 'name': 'television character'},
#    {'id': 'Q733786', 'name': 'monk'},
#    {'id': 'Q16358610', 'name': 'instructor'},
#    {'id': 'Q37226', 'name': 'teacher'},
#    {'id': 'Q1250916', 'name': 'warrior'}],
#   'features': {'ntoken': 1,
#    'popularity': 30,
#    'pos_score': 0.3,
#    'es_score': 35.66,
#    'es_diff_score': 4.3e-05,
#    'ed_score': 0.55,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.18,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q2091420',
#   'name': 'Avatar roku',
#   'descritpion': 'Wikimedia list article',
#   'types': [{'id': 'Q13406463', 'name': 'Wikimedia list article'}],
#   'features': {'ntoken': 1,
#    'popularity': 14,
#    'pos_score': 0.4,
#    'es_score': 35.59,
#    'es_diff_score': 4.6e-05,
#    'ed_score': 0.55,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.2,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q1640011',
#   'name': 'The Avatar',
#   'descritpion': 'title character of Avatar: The Last Airbender',
#   'types': [{'id': 'Q15632617', 'name': 'fictional human'},
#    {'id': 'Q15711870', 'name': 'animated character'},
#    {'id': 'Q15773347', 'name': 'film character'},
#    {'id': 'Q1114461', 'name': 'comics character'},
#    {'id': 'Q15773317', 'name': 'television character'},
#    {'id': 'Q733786', 'name': 'monk'},
#    {'id': 'Q16358610', 'name': 'instructor'},
#    {'id': 'Q37226', 'name': 'teacher'},
#    {'id': 'Q1250916', 'name': 'warrior'}],
#   'features': {'ntoken': 1,
#    'popularity': 30,
#    'pos_score': 0.48,
#    'es_score': 35.52,
#    'es_diff_score': 0.000125,
#    'ed_score': 0.6,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.8,
#    'cosine_similarity': 0.15,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q853499',
#   'name': 'Avatar crisis',
#   'descritpion': 'setting in the Dungeons & Dragons fictional universe',
#   'types': [{'id': 'Q4418079', 'name': 'campaign setting'},
#    {'id': 'Q559618', 'name': 'fictional universe'}],
#   'features': {'ntoken': 1,
#    'popularity': 26,
#    'pos_score': 0.59,
#    'es_score': 35.42,
#    'es_diff_score': 0.000271,
#    'ed_score': 0.46,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.17,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4827807',
#   'name': 'Avatar Land',
#   'descritpion': "themed area at Disney's Animal Kingdom in Florida",
#   'types': [{'id': 'Q30224326', 'name': 'themed area'}],
#   'features': {'ntoken': 1,
#    'popularity': 8,
#    'pos_score': 0.6,
#    'es_score': 35.41,
#    'es_diff_score': 3.3e-05,
#    'ed_score': 0.55,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.21,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.255,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P2046', 'o': '+12', 's': 0.006},
#     {'p': 'P8687', 'o': '+11411', 's': 0.176},
#     {'p': 'P8687', 'o': '+11551', 's': 0.174},
#     {'p': 'P8687', 'o': '+11070', 's': 0.181},
#     {'p': 'P2046', 'o': '+12', 's': 0.074},
#     {'p': 'P8687', 'o': '+11411', 's': 0.014},
#     {'p': 'P8687', 'o': '+11551', 's': 0.014},
#     {'p': 'P8687', 'o': '+11070', 's': 0.015}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P2046': 0.074, 'P8687': 0.181},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q2617247',
#   'name': 'Avatar universe',
#   'descritpion': 'fictional universe of the Avatar franchise',
#   'types': [{'id': 'Q559618', 'name': 'fictional universe'}],
#   'features': {'ntoken': 1,
#    'popularity': 10,
#    'pos_score': 0.61,
#    'es_score': 35.41,
#    'es_diff_score': 0.000209,
#    'ed_score': 0.4,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.14,
#    'p_subj_ne': 0.65,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0.65,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.001,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [{'p': 'P1445', 'o': 'Q24871', 's': 0.65}],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': []},
#   'pred': {'0': {}, '1': {'P1445': 0.65}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q237543',
#   'name': 'Narasimha avatar',
#   'descritpion': 'man-lion avatar of Vishnu',
#   'types': [{'id': 'Q83090', 'name': 'avatar'}],
#   'features': {'ntoken': 1,
#    'popularity': 46,
#    'pos_score': 0.24,
#    'es_score': 35.79,
#    'es_diff_score': 2e-05,
#    'ed_score': 0.38,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.36,
#    'cosine_similarity': 0.11,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q11012344',
#   'name': 'Sjabloon:Navigatie Avatar',
#   'descritpion': 'Wikimedia template',
#   'types': [{'id': 'Q11753321', 'name': 'Wikimedia navigational template'}],
#   'features': {'ntoken': 1,
#    'popularity': 19,
#    'pos_score': 0.31,
#    'es_score': 35.66,
#    'es_diff_score': 9e-05,
#    'ed_score': 0.24,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.2,
#    'cosine_similarity': 0.23,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q476824',
#   'name': 'Avatar Kalki',
#   'descritpion': 'Tenth incarnation of Vishnu in Hinduism',
#   'types': [{'id': 'Q83090', 'name': 'avatar'}],
#   'features': {'ntoken': 1,
#    'popularity': 50,
#    'pos_score': 0.42,
#    'es_score': 35.58,
#    'es_diff_score': 0.0,
#    'ed_score': 0.5,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.3,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q6705759',
#   'name': 'Modèle:Palette Avatar',
#   'descritpion': 'Wikimedia template page',
#   'types': [{'id': 'Q11753321', 'name': 'Wikimedia navigational template'}],
#   'features': {'ntoken': 1,
#    'popularity': 11,
#    'pos_score': 0.66,
#    'es_score': 35.38,
#    'es_diff_score': 0.000346,
#    'ed_score': 0.29,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.25,
#    'cosine_similarity': 0.13,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q790268',
#   'name': 'Avatar Comics',
#   'descritpion': 'American independent comic book publisher',
#   'types': [{'id': 'Q1114515', 'name': 'comic publishing company'},
#    {'id': 'Q1320047', 'name': 'book publisher'},
#    {'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q6881511', 'name': 'enterprise'}],
#   'features': {'ntoken': 1,
#    'popularity': 9,
#    'pos_score': 0.75,
#    'es_score': 35.31,
#    'es_diff_score': 6.3e-05,
#    'ed_score': 0.46,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.19,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.171,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+13129', 's': 0.153},
#     {'p': 'P8687', 'o': '+12735', 's': 0.158},
#     {'p': 'P8687', 'o': '+13129', 's': 0.012},
#     {'p': 'P8687', 'o': '+12735', 's': 0.013}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.158},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q1586696',
#   'name': 'Avatar beweging',
#   'descritpion': "series of courses run by Star's Edge Inc.",
#   'types': [{'id': 'Q5', 'name': 'human'},
#    {'id': 'Q482980', 'name': 'author'},
#    {'id': 'Q36180', 'name': 'writer'},
#    {'id': 'Q43845', 'name': 'businessperson'}],
#   'features': {'ntoken': 1,
#    'popularity': 5,
#    'pos_score': 0.8,
#    'es_score': 35.31,
#    'es_diff_score': 0.000732,
#    'ed_score': 0.4,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.2,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q830598',
#   'name': 'Avatar (1979–1983)',
#   'descritpion': 'American heavy metal band',
#   'types': [{'id': 'Q215380', 'name': 'musical group'}],
#   'features': {'ntoken': 1,
#    'popularity': 23,
#    'pos_score': 0.81,
#    'es_score': 35.28,
#    'es_diff_score': 8e-05,
#    'ed_score': 0.33,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.31,
#    'cosine_similarity': 0.23,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.559,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+3885', 's': 0.517},
#     {'p': 'P8687', 'o': '+3885', 's': 0.042}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.517},
#    '4': {},
#    '5': {}}},
#  {'id': 'Q1586696',
#   'name': 'Avatar Course',
#   'descritpion': "series of courses run by Star's Edge Inc.",
#   'types': [{'id': 'Q5', 'name': 'human'},
#    {'id': 'Q482980', 'name': 'author'},
#    {'id': 'Q36180', 'name': 'writer'},
#    {'id': 'Q43845', 'name': 'businessperson'}],
#   'features': {'ntoken': 1,
#    'popularity': 5,
#    'pos_score': 0.9,
#    'es_score': 35.22,
#    'es_diff_score': 0.000498,
#    'ed_score': 0.46,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.15,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [], '1': [], '2': [], '3': [], '4': [], '5': []},
#   'pred': {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}, '5': {}}},
#  {'id': 'Q4398281',
#   'name': 'Avatar Project',
#   'descritpion': 'organization that develops a network and community of researchers in the field of life extension',
#   'types': [{'id': 'Q163740', 'name': 'nonprofit organization'}],
#   'features': {'ntoken': 1,
#    'popularity': 10,
#    'pos_score': 0.93,
#    'es_score': 35.2,
#    'es_diff_score': 0.000191,
#    'ed_score': 0.43,
#    'jaccard_score': 0.5,
#    'jaccardNgram_score': 0.44,
#    'cosine_similarity': 0.16,
#    'p_subj_ne': 0,
#    'p_subj_lit': 0.09000000000000001,
#    'p_obj_ne': 0,
#    'desc': 0,
#    'descNgram': 0,
#    'cpa': 0,
#    'cpaMax': 0,
#    'cta': 0,
#    'ctaMax': 0,
#    'cea': 0.0,
#    'diff': 0},
#   'matches': {'0': [],
#    '1': [],
#    '2': [],
#    '3': [{'p': 'P8687', 'o': '+24100', 's': 0.083},
#     {'p': 'P8687', 'o': '+24100', 's': 0.007}],
#    '4': [],
#    '5': []},
#   'pred': {'0': {},
#    '1': {},
#    '2': {},
#    '3': {'P8687': 0.083},
#    '4': {},
#    '5': {}}}]
